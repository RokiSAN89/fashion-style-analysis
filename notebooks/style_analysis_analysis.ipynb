# %% [markdown]
# # 📊 Fashion Style Analysis
# This notebook explores fashion style aesthetics using Python.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %% [markdown]
# ## 📥 Load your dataset

# %%
# df = pd.read_csv('data/your_dataset.csv')
df.head()
